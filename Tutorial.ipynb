# %% [markdown]
# # Tutorials

# %% [markdown]
# https://riptutorial.com/pandas/example/6232/datareader-basic-example--yahoo-finance-

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
# Only get the adjusted close.
aapl = pdr.DataReader("AAPL", 
                       start='2015-1-1', 
                       end='2015-12-31', 
                       data_source='yahoo')['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Convert the adjusted closing prices to cumulative returns.
returns = aapl.pct_change()

# %%
aapl.plot(title='AAPL Adj. Closing Price')
# Out:
# <AxesSubplot:title={'center':'AAPL Adj. Closing Price'}, xlabel='Date'>

# %% [markdown]
# https://www.learndatasci.com/tutorials/python-finance-part-yahoo-finance-api-pandas-matplotlib/

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt
import pandas as pd

# %%
tickers = ['AAPL', 'MSFT', 'NIO', 'BMBL']
start_date = '2016-01-01'
end_date = '2021-03-19'

panel_data = pdr.DataReader(tickers, start_date, end_date)
panel_data.tail(10)
# Out:
# [*********************100%***********************]  4 of 4 completed
#              Adj Close                                         Close  \
#                   AAPL       BMBL        MSFT        NIO        AAPL
# Date
# 2021-03-05  121.419998  61.650002  231.600006  38.110001  121.419998
# 2021-03-08  116.360001  60.500000  227.389999  35.209999  116.360001
# 2021-03-09  121.089996  63.299999  233.779999  41.349998  121.089996
# 2021-03-10  119.980003  62.910000  232.419998  41.320000  119.980003
# 2021-03-11  121.959999  69.760002  237.130005  46.029999  121.959999
# 2021-03-12  121.029999  69.260002  235.750000  45.500000  121.029999
# 2021-03-15  123.989998  73.470001  234.809998  44.930000  123.989998
# 2021-03-16  125.570000  73.000000  237.710007  43.680000  125.570000
# 2021-03-17  124.760002  72.669998  237.039993  44.759998  124.760002
# 2021-03-18  120.529999  66.190002  230.720001  41.630001  120.529999
#
#                                                     High             ...  \
#                  BMBL        MSFT        NIO        AAPL       BMBL  ...
# Date                                                                 ...
# 2021-03-05  61.650002  231.600006  38.110001  121.940002  62.290001  ...
# 2021-03-08  60.500000  227.389999  35.209999  121.000000  63.470001  ...
# 2021-03-09  63.299999  233.779999  41.349998  122.059998  63.930000  ...
# 2021-03-10  62.910000  232.419998  41.320000  122.169998  65.500000  ...
# 2021-03-11  69.760002  237.130005  46.029999  123.209999  76.489998  ...
# 2021-03-12  69.260002  235.750000  45.500000  121.169998  72.199997  ...
# 2021-03-15  73.470001  234.809998  44.930000  124.000000  74.800003  ...
# 2021-03-16  73.000000  237.710007  43.680000  127.220001  74.580002  ...
# 2021-03-17  72.669998  237.039993  44.759998  125.860001  72.919998  ...
# 2021-03-18  66.190002  230.720001  41.630001  123.180000  71.180000  ...
#
#                    Low                   Open                         \
#                   MSFT        NIO        AAPL       BMBL        MSFT
# Date
# 2021-03-05  226.460007  31.910000  120.980003  60.610001  229.520004
# 2021-03-08  227.130005  34.900002  120.930000  59.430000  231.369995
# 2021-03-09  231.669998  36.520000  119.029999  62.490002  232.880005
# 2021-03-10  232.039993  40.250000  121.690002  65.300003  237.000000
# 2021-03-11  234.309998  42.799999  122.540001  71.099998  234.960007
# 2021-03-12  233.229996  42.759998  120.400002  67.669998  234.009995
# 2021-03-15  231.809998  44.380001  121.410004  69.440002  234.960007
# 2021-03-16  235.940002  43.169998  125.699997  74.010002  236.279999
# 2021-03-17  233.229996  41.330002  124.050003  71.089996  236.149994
# 2021-03-18  230.330002  41.450001  122.879997  70.250000  232.559998
#
#                           Volume
#                   NIO       AAPL       BMBL      MSFT          NIO
# Date
# 2021-03-05  39.240002  153590400  3035600.0  41842100  270244200.0
# 2021-03-08  36.970001  153918600  1903900.0  35245900  142168500.0
# 2021-03-09  37.480000  129159600  1390900.0  33034000  175901000.0
# 2021-03-10  43.500000  111760400  2189800.0  29733000  190337700.0
# 2021-03-11  44.439999  102753600  8664300.0  29896000  134109800.0
# 2021-03-12  43.509998   87963400  2822900.0  22647900  113259600.0
# 2021-03-15  45.549999   92403800  2601500.0  26034900   74013600.0
# 2021-03-16  45.040001  114740000  1553300.0  27717700   83885500.0
# 2021-03-17  41.900002  111437500  2210900.0  29500700   95591200.0
# 2021-03-18  43.299999  121229700  2649700.0  34833000   71159900.0
#
# [10 rows x 24 columns]

# %%
df=pd.DataFrame(panel_data)

# %%
df.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'MSFT'),
#             ('Adj Close',  'NIO'),
#             ('Adj Close', 'BMBL'),
#             (    'Close', 'AAPL'),
#             (    'Close', 'MSFT'),
#             (    'Close',  'NIO'),
#             (    'Close', 'BMBL'),
#             (     'High', 'AAPL'),
#             (     'High', 'MSFT'),
#             (     'High',  'NIO'),
#             (     'High', 'BMBL'),
#             (      'Low', 'AAPL'),
#             (      'Low', 'MSFT'),
#             (      'Low',  'NIO'),
#             (      'Low', 'BMBL'),
#             (     'Open', 'AAPL'),
#             (     'Open', 'MSFT'),
#             (     'Open',  'NIO'),
#             (     'Open', 'BMBL'),
#             (   'Volume', 'AAPL'),
#             (   'Volume', 'MSFT'),
#             (   'Volume',  'NIO'),
#             (   'Volume', 'BMBL')],
#            names=['Attributes', 'Symbols'])
